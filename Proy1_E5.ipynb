# %% [markdown]
# # Matemáticas Discretas - Funciones Recursivas 💻
# ## Proyecto 1 - Equipo 5
# **Integrantes:**
# 1. Borges González Karla Marisol
# 2. González Álvarez María Fernanda
# 3. González Aranda Mario Joel
#
# *Descripción:*
# Implementar en un Jupyter Notebook mediante el kernel iPython los siguientes algoritmos	y/o	funciones recursivas.

# %% [markdown]
# ## 1. Factorial de N ✨
#
# > **Datos de entrada**: `n`, número que se calculará su factorial, con $n\geq0$.
# **Datos de salida**: `fact`, factorial de `n`.
#
# El siguiente código, define la función `factorial` que calcula el factorial de un número entero $n$ dado. El factorial de un número entero positivo $n$ se define como el producto de todos los números enteros positivos desde $n$ hasta $1$. Considerando que $0! =1$, es decir: $n! = n \times (n-1) \times(n-2)\times \cdots \times 1$. Recursivamente, esto es:
# $n! = \begin{cases} n\times (n-1)! & \text{ si } n>0 \\ 1 & \text{ si } n=0 \end{cases}$
#
# La función `factorial` utiliza una estructura de control llamada `if... else` para verificar si el valor de $n$ es igual a $0$. Si ese es el caso, la función devuelve $1$ porque el factorial de $0=1$. De lo contrario, la función utiliza la recursividad para calcular el factorial de $n - 1$ y luego lo multiplica por $n$.
#
# El código también utiliza un bucle `while` para verificar si el valor de $n$ es negativo. Si es así, se muestra un mensaje de error y se solicita al usuario que ingrese un valor positivo.
#
# Finalmente, el código llama a la función `factorial` con el valor de $n$ ingresado por el usuario y asigna el resultado a la variable `fact`. Luego, se muestra el resultado del cálculo del factorial utilizando una cadena de formato que incluye el valor de $n$ y su factorial correspondiente.

# %%
def factorial(n):
    if n == 0:
        return 1
    else:
        return n * factorial(n - 1)
    
print("Calcula el factorial de n")
n = int(input("Ingrese el factorial a calcular: "))

while n < 0:
    print("El valor de n no puede ser negativo")
    n = int(input("Ingrese el factorial a calcular: "))
    
fact = factorial(n)
print(f"El factorial de {n} es: {fact}")
# Out:
# Calcula el factorial de n
# Ingrese el factorial a calcular: -9
# El valor de n no puede ser negativo
# Ingrese el factorial a calcular: 5
# El factorial de 5 es: 120

# %% [markdown]
# ## 2. Fibonacci ✨
#
# > **Datos de entrada**: `n`, término a calcular de la secuencia de Fibonacci, con $n\geq0$.
# **Datos de salida**: `fibo_term`, término `n` de la secuencia de Fibonacci.
#
# A continuación, el código define la función `fibo` que calcula el n-ésimo término de la serie de Fibonacci. La serie de Fibonacci es una secuencia de números en la que cada número es la suma de los dos números anteriores.
# Es decir, tenemos: $a_{n}=\begin{cases}
# 0 & \text{ si } n=0 \\
# 1 & \text{ si } n=1 \\
# 1 & \text{ si } n=2 \\
# a_{n-1}+a_{n-2} & \text{ si } n>2
# \end{cases}$
#
# La función `fibo` utiliza una estructura de control llamada `if... else` para verificar si el valor de $n$ es menor o igual a $1$. Si ese es el caso, la función devuelve $n$, ya que el primer y segundo término de la serie de Fibonacci son $0$ y $1$, respectivamente.
#
# El código también utiliza un bucle `while` para verificar si el valor de $n$ es negativo. Si es así, se muestra un mensaje de error y se solicita al usuario que ingrese un valor positivo.
#
# Finalmente, el código llama a la función `fibo` con el valor de $n$ ingresado por el usuario y asigna el resultado a la variable `fibo_term`. Luego, se muestra el resultado del cálculo del n-ésimo término de la serie de Fibonacci utilizando una cadena de formato que incluye el valor de $n$ y su correspondiente término en la serie.

# %%
def fibo(n):
    if n <= 1:
        return n
    else: 
        return fibo(n - 1) + fibo(n - 2)
    
print("Calcula el n-ésimo término de Fibonacci")

n = int(input("Ingrese el n-ésimo termino a calcular: "))

while n < 0:
    print("El valor de n no puede ser negativo")
    n = int(input("Ingrese el término a calcular: "))

fibo_term = fibo(n)
print(f"El término a_{n} = {fibo_term}")
# Out:
# Calcula el n-ésimo término de Fibonacci
# Ingrese el n-ésimo termino a calcular: 0
# El término a_0 = 0

# %% [markdown]
# ## 3. Torres de Hanoi ✨
#
# > **Datos de entrada**: `n`, número de discos que el usuario desea mover, con $n\geq0$; `a`, que representa la torre inicial, `b`, la torre auxiliar, y `c` la torre de destino.
# **Datos de salida**: `mov`, número de movimientos para mover `n` discos de la torre inicial al objetivo.
#
# El siguiente código resuelve el problema de la torre de Hanoi, que consiste en mover una pila de discos de una torre a otra, utilizando una tercera torre como espacio temporal. El objetivo es mover la pila de discos de una torre inicial a una torre objetivo, siguiendo una serie de reglas que indican que solo se puede mover un disco a la vez, y que un disco más grande no puede estar sobre uno más pequeño.
#
# El problema de las torres de hanoi recursivamente es:
# $a_{n}=\begin{cases}
# 0 & \text{ si } n=0 \\
# 1 & \text{ si } n=1 \\
# 2a_{n-1}+1 & \text{ si } n>1
# \end{cases}$
#
# La función `hanoi` implementa la solución recursiva para el problema de la torre de Hanoi, tomando en cuenta que se cuenta con 3 torres. Si el número de discos es igual a $1$, la función imprime un mensaje que indica cómo mover el disco desde la torre $a$ a la torre $b$, y devuelve $1$. De lo contrario, la función se llama a sí misma tres veces con diferentes parámetros para mover los discos. La primera llamada mueve los $n-1$ discos más pequeños de la torre $a$ a la torre temporal, utilizando la torre $b$ como espacio temporal. La segunda llamada mueve el disco más grande de la torre $a$ a la torre $b$. La tercera llamada mueve los $n-1$ discos más pequeños de la torre temporal a la torre $b$, utilizando la torre $a$ como espacio temporal. La función devuelve el número total de movimientos realizados para mover los discos.
#
# El código también utiliza un bucle `while` para verificar si el valor de $n$ es negativo. Si es así, se muestra un mensaje de error y se solicita al usuario que ingrese un valor positivo.
#
# Finalmente, el código llama a la función `hanoi` con los parámetros necesarios para mover los `n` discos ingresados por el usuario, y muestra el número total de movimientos necesarios para mover los discos utilizando una cadena de formato.

# %%
def hanoi(a, temp, b, n):
    if n == 1:
        print(f"Mueve disco de torre {a}, a torre {b}")
        return 1
    else:
        mov = hanoi(a, b, temp, n-1)
        mov += hanoi(a, temp, b, 1)
        mov += hanoi(temp, a, b, n-1)
        
        return mov
    
print("Calcula número de movimientos para mover n discos")

n = int(input("Ingrese el n° de discos: "))

while n < 0:
    print("El valor de n no puede ser negativo")
    n = int(input("Ingrese el n° de discos: "))

    
if n == 0:
    print(f"Se necesitan 0 movimientos para mover {n} discos")
else:
    mov = hanoi(1, 2, 3, n)
    print(f"Se necesitan {mov} movimientos para mover {n} discos")

# %% [markdown]
# ## 4. Multiplicación Entera ✨
#
# > **Datos de entrada**: `a` y `b`, son los números a multiplicar, con $a,b\geq0$.
# **Datos de salida**: `prod`, es el producto de $a\times b$.
#
# El siguiente código implementa la función `multi_entera` que toma dos números enteros $a$ y $b$ como entrada y devuelve su multiplicación como salida. La multiplicación se realiza mediante un enfoque de recursión.
#
# En la función, se comprueba si $b=0$. Si es así, la función devuelve cero, ya que cualquier número multiplicado por cero es cero. Si $b \neq 0$, la función devuelve la suma de $a$ y la llamada a sí misma con los argumentos `a` y `b-1`. Esta llamada a sí misma se realiza de forma recursiva hasta que `b` sea cero, en cuyo caso la función devuelve cero.
# Recursivamente, entonces: $a\times b=\begin{cases}
# a + (a\times (b-1)) & \text{ si } b>0 \\
# 0 & \text{ si } b=0 \\
# \end{cases}$
#
# Después de definir la función `multi_entera`, se solicita al usuario que ingrese dos números enteros $a$ y $b$ y se validan que ambos números no sean negativos.
#
# Finalmente, se llama a la función `multi_entera` con los valores de $a$ y $b$ ingresados por el usuario y se imprime el resultado de la multiplicación en la pantalla.

# %%
def multi_entera(a, b):
    if b == 0:
        return 0
    else:
        return a + multi_entera(a, b-1)

print("Calcule la multiplicación de dos enteros, a * b")

a = int(input("Ingrese a: "))
while a < 0:
    print("a no puede ser un número negativo")
    a = int(input("Ingrese a: "))
b = int(input("Ingrese b: "))
while b < 0:
    print("b no puede ser un número negativo")
    b = int(input("Ingrese b: "))

prod = multi_entera(a, b)
print(f"El resultado de multiplicar {a} por {b} es: {prod}")

# %% [markdown]
# ## 5. Exponenciación Entera ✨
#
# > **Datos de entrada**: `a`, como la base, y `b`, como el exponente, con $a,b\geq0$. En este caso, `a` y `b` no pueden ser 0 simultáneamente, es decir: $(a=0 \wedge b>0 )\vee (a>0 \wedge b = 0 )$.
# **Datos de salida**: `elev`, el resultado de elevar $a^b$.
#
# A continuación, se implementa la función `expo`, que calcula el resultado de elevar un número entero a una potencia entera. La función toma dos argumentos: `a` y `b`. La función utiliza una técnica de recursión para calcular la exponenciación.
#
# La definición recursiva de esta operación, se deriva de la definición de la potencia como una multiplicación abreviada, es decir: $a^b=a\times a^{b-1}$
#
# Sin embargo, se pueden buscar otras formas de definir recursivamente la operación propuesta, y obtener beneficios en términos de eficiencia del algoritmo. Considerándose este hecho, puede definirse recursivamente la operación potencia como: $a^b = \begin{cases}
# a^{b/2} \times a^{b/2} & \text{ si } b>0 \wedge b~es~par \\
# a \times a^{b-1} & \text{ si } b>0 \wedge b~es~impar \\
# 1 & \text{ si } b=0
# \end{cases}$
#
# Después de definir la función `expo`, el código le pide al usuario que ingrese dos números enteros $a$ y $b$. Si $a$ o $b$ es menor que cero, se le pide al usuario que vuelva a ingresar el número hasta que ingrese un número válido. Si tanto $a$ como $b$ son cero, la función imprime un mensaje indicando que el resultado está indefinido. De lo contrario, el código llama a la función `expo` con los valores de `a` y `b` ingresados y muestra el resultado de la exponenciación.

# %%
def expo(a, b):
    if b == 0:
        return 1
    elif b % 2 == 0:
        temp = expo(a, b/2)
        return temp * temp
    else:
        return a * expo(a, b - 1)

print("Calcule la exponenciación de dos enteros, a^b")

a = int(input("Ingrese a: "))
while a < 0:
    print("a no puede ser un número negativo")
    a = int(input("Ingrese a: "))
b = int(input("Ingrese b: "))
while b < 0:
    print("b no puede ser un número negativo")
    b = int(input("Ingrese b: "))

if a == 0 and b == 0:
    print(f"El resultado de elevar {a} a la {b} está indefinido")  
else:
    elev = expo(a, b)
    print(f"El resultado de elevar {a} a la {b} potencia es: {elev}")

# %% [markdown]
# ## 6. Máximo Común Divisor ✨
#
# > **Datos de entrada**: `a` y `b`, de los cuales calcularemos su MCD. Igualmente, `a` y `b` no pueden ser 0 simultaneamente, es decir: $(a=0 \wedge b>0 )\vee (a>0 \wedge b = 0 )$
# **Datos de salida**: `maxcd`, el MCD entre `a` y `b`.
#
# El siguiente código, es una implementación del algoritmo de Euclides para calcular el MCD de dos números enteros. La función se llama `mcd` y toma dos argumentos: `a` y `b`.
#
# En este caso, la función utiliza una técnica de recursión, pero se basa en la identidad de Euclides para calcular el MCD. La identidad de Euclides establece que el MCD de dos números $a$ y $b$ es igual al MCD de $b$ y el resto de $a$ dividido por $b$.
#
# Es decir:
# $mcd(a,b) = \begin{cases}
# b & \text{ si } a=0 \\
# a & \text{ si } b=0 \\
# mcd(b, a~\%~b) & \text{ si } (a=0 \wedge b>0 )\vee (a>0 \wedge b = 0)
# \end{cases}$
#
# Por lo tanto, la función comienza con las siguientes condiciones: si $b=0$, la función devuelve el $a$, y si $a=0$, la función devuelve el $b$. Si ambos números son iguales a cero, la función indica que el MCD no está definido. Si ninguna de las condiciones base anteriores se cumple, la función llama a sí misma con los argumentos `b` y `a % b`, que es el resto de la división de $a$ entre $b$. Esta llamada recursiva continúa hasta que se alcanza una de las condiciones base e imprime `maxcd` como el MCD entre $a$ y $b$

# %%
def mcd(a, b):
    if b == 0:
        return a
    elif a == 0:
        return b
    else:
        return mcd(b, a % b)

print("Calcule el máximo comun divisor de a y b")

a = int(input("Ingrese a: "))
while a < 0:
    print("a no puede ser un número negativo")
    a = int(input("Ingrese a: "))
b = int(input("Ingrese b: "))
while b < 0:
    print("b no puede ser un número negativo")
    b = int(input("Ingrese b: "))

if a == 0 and b == 0:
    print(f"El máximo comun divisor de 0 y 0 no está definido")  
else:
    maxcd = mcd(a, b)
    print(f"El MCD de {a} y {b} es {maxcd}")

# %% [markdown]
# ## 7. Número Mayor ✨
#
# > **Datos de entrada**: `nums`, números que el usuario va ingresando separados por un espacio, los números son reales.
# **Datos de salida**: `max_num`, el número mayor de entre la lista de números ingresada.
#
# Este código define una función `max_fun` que encuentra el número máximo en una lista de números `nums` utilizando la técnica de recursión.
#
# Si la lista tiene más de un número, la función extrae el último número de la lista utilizando el método `pop()` de Python y lo almacena en la variable `numero`. Luego, la función llama a sí misma con la lista restante y almacena el valor devuelto en la variable `max_act`, que representa el número que es mayor por el momento.
#
# La función compara `max_act` con `numero`. Si `max_act` es mayor que `numero`, devuelve `max_act`. De lo contrario, devuelve `numero`.
#
# Luego, el programa principal solicita al usuario que ingrese una lista de números separados por espacios y crea una lista de números a partir de ella, ya que Python interpretaría lo ingresado por el usuario como `string`. Si la lista está vacía, el programa solicita al usuario que ingrese una lista de números nuevamente hasta que se ingrese al menos un número.
#
# Finalmente, el programa llama a la función `max_fun` con la lista de números y muestra el número máximo en la lista.

# %%
def max_fun(nums):
    if len(nums) == 1:
        return nums[0]
    else:
        numero = float(nums.pop())
        max_act = max_fun(nums)
        if max_act > numero:
            return max_act
        else:
            return numero

print("Calcule el número máximo de un conjunto de números")

nums = input("Ingrese una lista de números separados por un espacio: ")
num_a_lista = [float(n) for n in nums.split()]

while len(num_a_lista) == 0:
    nums = input("No ha ingresado ningun número. Ingrese una lista de números separados por un espacio: ")
    num_a_lista = [float(n) for n in nums.split()]

max_num = max_fun(num_a_lista)

print(f"El número máximo de la lista es: {max_num}")

# %% [markdown]
# ## 8. Número Menor ✨
#
# > **Datos de entrada**: `nums`, números que el usuario va ingresando separados por un espacio, los números son reales.
# **Datos de salida**: `min_num`, el número menor de entre la lista de números ingresada.
#
# Este código define una función `min_fun` que encuentra el número menor en una lista de números `nums` utilizando la técnica de recursión.
#
# Si la lista tiene más de un número, la función extrae el último número de la lista utilizando el método `pop()` de Python y lo almacena en la variable `numero`. Luego, la función llama a sí misma con la lista restante y almacena el valor devuelto en la variable `min_act`, que representa el número que es menor por el momento.
#
# La función compara `min_act` con `numero`. Si `min_act` es menor que `numero`, devuelve `min_act`. De lo contrario, devuelve `numero`.
#
# Luego, el programa principal solicita al usuario que ingrese una lista de números separados por espacios y crea una lista de números a partir de ella, ya que Python intepretaría lo ingresado por el usuario como `string`. Si la lista está vacía, el programa solicita al usuario que ingrese una lista de números nuevamente hasta que se ingrese al menos un número.
#
# Finalmente, el programa llama a la función `min_fun` con la lista de números y muestra el número menor en la lista.

# %%
def min_fun(nums):
    if len(nums) == 1:
        return nums[0]
    else:
        numero = float(nums.pop())
        min_act = min_fun(nums)
        if min_act < numero:
            return min_act
        else:
            return numero

print("Calcule el número mínimo de un conjunto de números")

nums = input("Ingrese una lista de números separados por un espacio: ")
num_a_lista = [float(n) for n in nums.split()]

while len(num_a_lista) == 0:
    nums = input("No ha ingresado ningun número. Ingrese una lista de números separados por un espacio: ")
    num_a_lista = [float(n) for n in nums.split()]

min_num = min_fun(num_a_lista)

print(f"El número mínimo de la lista es: {min_num}")

# %% [markdown]
# ## 9. Número Combinatorio ✨
#
# > **Datos de entrada**: `n`,es el número total de elementos, y `k` el número de elementos a seleccinar.
# **Datos de salida**: `result`, el número de combinaciones totales de `n` en `k`.
#
# Este código es una implementación de la fórmula matemática para calcular el número combinatorio de $n$ en $k$, también conocido como coeficiente binomial.
#
# Para elegir $k$ elementos de un conjunto de $n$ elementos, podemos tomar un elemento específico como parte de esos $k$ elementos o no. Si tomamos un elemento específico como parte de los $k$ elementos, entonces debemos elegir $k-1$ elementos de los $n-1$ elementos restantes. Si no tomamos ese elemento específico como parte de los $k$ elementos, entonces debemos elegir $k$ elementos de los $n-1$ elementos restantes.
#
# Al sumar estas dos opciones, obtenemos el número total de formas de elegir $k$ elementos de un conjunto de $n$ elementos. Y debido a que la fórmula se define recursivamente, podemos utilizarla para calcular el número combinatorio de cualquier par de valores $n$ y $k$.
#
# Recursivamente, esto es: $C_{n, k}=C_{n-1,~k-1}+C_{n-1,~k}$
#
# La función definida al inicio, `combinaciones`, utiliza recursión para calcular el número combinatorio. Si $k=0 \vee k=n$, entonces retorna $1$, porque la fórmula combinatoria de un conjunto vacío o del conjunto completo siempre es $1$. De lo contrario, utiliza la fórmula recursiva mencionada anteriormente.
#
# El programa luego solicita al usuario que ingrese los valores de `n` y `k`, y los valida para asegurarse de que no sean números negativos. Si $k$ es mayor que $n$, significa que el número combinatorio no está definido y se imprime un mensaje que indica esto. Si $k$ es menor o igual que $n$, el programa utiliza la función `combinaciones` para calcular el número combinatorio y lo imprime en pantalla.

# %%
def combinaciones(n, k):
    if k == 0 or k == n:
        return 1
    else:
        return combinaciones(n-1, k-1) + combinaciones(n-1, k)
    
print("Calcule el número combinatorio de n en k, enteros")

n = int(input("Ingrese n: "))
while n < 0:
    print("n no puede ser un número negativo")
    n = int(input("Ingrese n: "))
k = int(input("Ingrese k: "))
while k < 0:
    print("k no puede ser un número negativo")
    k = int(input("Ingrese k: "))

if k > n:
    print(f"El número combinatorio de {n} en {k} no está definido")  
else:
    result = combinaciones(n, k)
    print(f"El número combinatorio de {n} en {k} es {result}")

# %% [markdown]
# ## 10. Reversa de una Lista ✨
#
# > **Datos de entrada**: `nums`,es la de números ingresada por el usuario, estos pueden ser reales.
# **Datos de salida**: `lista_rev`, es la lista original al revés.
#
# Este programa calcula la reversa de una lista de números ingresada por el usuario.
#
# Primero, se define una función `reversa` que toma una lista `nums` como argumento y utiliza recursión para calcular su reversa. Si la longitud de la lista es igual a $1$, entonces se retorna la misma lista porque una lista de un solo elemento es igual a su reversa. De lo contrario, se utiliza la fórmula recursiva: la reversa de la lista `nums` es igual a la concatenación del último elemento de `nums` con la reversa del resto de `nums`, es decir, `nums[:-1]`.
#
# Después, el programa solicita al usuario que ingrese una lista de números separados por un espacio, y la convierte en una lista de enteros. Si la lista está vacía, se le pide al usuario que ingrese una lista válida hasta que lo haga.
#
# Luego, se llama a la función reversa con la lista de números ingresada por el usuario y se almacena el resultado en una variable `lista_rev`. Finalmente, se imprime en pantalla la lista original y su reversa.

# %%
def reversa(nums):
    if len(nums) == 1:
        return nums
    else:
        return [nums[-1]] + reversa(nums[:-1])

print("Calcule la reversa de una lista")

nums = input("Ingrese una lista de números separados por un espacio: ")
num_a_lista = [float(n) for n in nums.split()]

while len(num_a_lista) == 0:
    nums = input("No ha ingresado ningun número. Ingrese una lista de números separados por un espacio: ")
    num_a_lista = [float(n) for n in nums.split()]

lista_rev = reversa(num_a_lista)

print(f"La lista {num_a_lista} al revés es {lista_rev}")
